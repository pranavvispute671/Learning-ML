# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
from

# %%
x = [i for i in range(1,10)]
y = [i**5 for i in x]

# %%
plt.plot(x,y)
plt.title("Power of 5")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()
